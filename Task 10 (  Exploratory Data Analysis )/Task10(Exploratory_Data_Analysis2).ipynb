# %% [markdown]
# ## Bivariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_excel("/content/drive/Shareddrives/mayur/innomatics/EDA/aspiring_minds_employability_outcomes_2015.xlsx")
data.shape
# Out:
# (3998, 39)

# %%
data.head(2)
# Out:
#   Unnamed: 0      ID  Salary  ... extraversion nueroticism openess_to_experience
# 0      train  203097  420000  ...       0.5269      1.3549               -0.4455
# 1      train  579905  500000  ...       1.2396     -0.1076                0.8637
#
# [2 rows x 39 columns]

# %%
#data_cat=data[["12percentage,12board,collegeGPA,Gender,CollegeTier,Degree,Specialization,CollegeCityTier,CollegeState"][Salary, Job Titles, and Job Locations]]

# %% [markdown]
# ###  Analysis of Salary with categorical variable and numerical variable

# %% [markdown]
# **Analysis of Salary with Gender**

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Gender', y='Salary',hue='Degree',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * Female with M.tech/M.E degree has highest salary.
# * Male with M.sc(tech) degree has highest salry

# %% [markdown]
# **Analysis of Salary with CollegeTier**

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='CollegeTier', y='Salary',hue='Degree',kind='bar',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# * Student with college tier 1 and M.tech degree has highest salary
# * Student with college tier 2 and B.tech degree has highest salry.

# %% [markdown]
# **Analysis of Salary with Specialization**

# %%
plt.figure(figsize = (10,4))
sns.barplot('Specialization', 'Salary', data =data, color = 'r', label= 'Specialization')
plt.xticks(rotation=90)
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Specialization with polymer technology has highest salary
# * Computer networking has second highest salary

# %% [markdown]
# **Analysis of Salary with CollegeState**

# %%
plt.figure(figsize = (10,4))
sns.barplot('CollegeState', 'Salary', data =data, color = 'r', label= 'CollegeState')
plt.xticks(rotation=90)
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Meghalaya student get highest salary.
# * Uninion territory get lowest salary.

# %% [markdown]
# **Analysis of Salary with Quant**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Quant', 'Salary', data =data, color = 'r', label= 'Salary with Quant')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Quant marks and salary is directly proportional highest the marks highest salary

# %% [markdown]
# **Analysis of Salary with ComputerProgramming**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('ComputerProgramming', 'Salary', data =data, color = 'r', label= 'Salary with ComputerProgramming')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Marks between 600 to 800 has highest salary

# %% [markdown]
# **Analysis of Salary with ElectronicsAndSemicon**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('ElectronicsAndSemicon', 'Salary', data =data, color = 'r', label= 'Salary with ElectronicsAndSemicon')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * ElectronicsAndSemicon marks and salary is directly proportional highest the marks highest salary

# %% [markdown]
# **Analysis of Salary with ComputerScience**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('ComputerScience', 'Salary', data =data, color = 'r', label= 'Salary with ComputerScience')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * ComputerScience marks and salary is directly proportional highest the marks highest salary.
# * Marks between 600 to 700 get highest salary.

# %% [markdown]
# **Analysis of Salary with ElectricalEngg**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('ElectricalEngg', 'Salary', data =data, color = 'r', label= 'Salary with ElectricalEngg')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * ElectricalEngg marks and salary is directly proportional highest the marks highest salary.
# * Student marks between 600-700 get highest salary.

# %% [markdown]
# **Analysis of Salary with CivilEngg**

# %%
plt.figure(figsize = (10,4))
sns.lineplot('CivilEngg', 'Salary', data =data, color = 'r', label= 'Salary with CivilEngg')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# * Student marks between 400-500 get highest salary.

# %% [markdown]
# ###  Analysis of Designation with categorical variable and numerical variable

# %% [markdown]
# **Analysis of Designation with Gender**

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="Degree", size=4) \
   .map(plt.scatter, "Gender", "Designation") \
   .add_legend();
plt.show();

# %%
data2=data.groupby('Specialization')
data2.head()
# Out:
#      Unnamed: 0       ID  ...  nueroticism openess_to_experience
# 0         train   203097  ...      1.35490               -0.4455
# 1         train   579905  ...     -0.10760                0.8637
# 2         train   810601  ...     -0.86820                0.6721
# 3         train   267447  ...     -0.40780               -0.9194
# 4         train   343523  ...      0.09163               -0.1295
# ...         ...      ...  ...          ...                   ...
# 3712      train  1168773  ...     -1.50210               -0.0943
# 3755      train  1242113  ...     -0.23440                0.4805
# 3793      train  1175525  ...      1.92070               -2.2021
# 3873      train   781902  ...      1.16010                1.0554
# 3929      train   336937  ...      0.88483               -0.4455
#
# [158 rows x 39 columns]
